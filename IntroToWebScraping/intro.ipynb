# %% [markdown]
# # BeautifulSoup and Requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
# The url from where the data is to be scrapped
url = 'https://www.scrapethissite.com/pages/forms/'

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# # Find and Find_all

# %%
soup.find('div')
# Out:
# <div class="container">
# <div class="col-md-12">
# <ul class="nav nav-tabs">
# <li id="nav-homepage">
# <a class="nav-link hidden-sm hidden-xs" href="/">
# <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                 Scrape This Site
#                             </a>
# </li>
# <li id="nav-sandbox">
# <a class="nav-link" href="/pages/">
# <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                 Sandbox
#                             </a>
# </li>
# <li id="nav-lessons">
# <a class="nav-link" href="/lessons/">
# <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                 Lessons
#                             </a>
# </li>
# <li id="nav-faq">
# <a class="nav-link" href="/faq/">
# <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                 FAQ
#                             </a>
# </li>
# <li class="pull-right" id="nav-login">
# ...

# %%
soup.find_all('div')
# Out:
# [<div class="container">
#  <div class="col-md-12">
#  <ul class="nav nav-tabs">
#  <li id="nav-homepage">
#  <a class="nav-link hidden-sm hidden-xs" href="/">
#  <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                  Scrape This Site
#                              </a>
#  </li>
#  <li id="nav-sandbox">
#  <a class="nav-link" href="/pages/">
#  <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                  Sandbox
#                              </a>
#  </li>
#  <li id="nav-lessons">
#  <a class="nav-link" href="/lessons/">
#  <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                  Lessons
#                              </a>
#  </li>
#  <li id="nav-faq">
#  <a class="nav-link" href="/faq/">
#  <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                  FAQ
#                              </a>
#  </li>
# ...

# %% [markdown]
# ### Ex 1. Scraping a simple paragraph from the html text.

# %%
soup.find_all('p')
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>,
#  <p>
#  <i class="glyphicon glyphicon-education"></i> There are <a href="/lessons/">8 video lessons</a> that show you how to scrape this page.
#                          </p>,
#  <p>
#
#                                  Data via
#                                  <a class="data-attribution" href="http://www.opensourcesports.com/hockey/" target="_blank">http://www.opensourcesports.com/hockey/</a>
#  </p>]

# %%
soup.find_all('p', class_ = 'lead')
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>]

# %%
soup.find_all('p', class_ = 'lead').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 soup.find_all('p', class_ = 'lead').text
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\element.py:2428, in ResultSet.__getattr__(self, key)
#    2426 def __getattr__(self, key):
#    2427     """Raise a helpful exception to explain a common code fix."""
# -> 2428     raise AttributeError(
#    2429         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2430     )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.find('p', class_ = 'lead').text
# Out:
# '\n                            Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.\n                        '

# %%
soup.find('p', class_ = 'lead').text.strip()
# Out:
# 'Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.'

# %% [markdown]
# ### Ex 2. Scrapping Team Name heading from the table.

# %%
soup.find_all('th')
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
soup.find('th').text.strip()
# Out:
# 'Team Name'

# %% [markdown]
# # Scraping the Table data from a Real Website + Pandas

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_India'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of largest companies in India - Wikipedia
#   </title>
#   <script>
# ...

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue<br/><small>(in  <b>₹ Crore</b>)</small>
# </th>
# <th>Revenue growth
# </th>
# <th>Profits<br/><small>(in  <b>₹ Crore</b>)</small>
# </th>
# <th>Headquarters
# </th>
# <th><a href="/wiki/List_of_public_sector_undertakings_in_India" title="List of public sector undertakings in India">State Controlled</a>
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a class="mw-redirect" href="/wiki/Reliance_Industries_Limited" title="Reliance Industries Limited">Reliance Industries Limited</a>
# </td>
# <td><a href="/wiki/Petroleum_industry" title="Petroleum industry">Oil and gas</a>
# </td>
# <td style="text-align:center;">920,274
# </td>
# ...

# %%
table.find_all('th')
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue<br/><small>(in  <b>₹ Crore</b>)</small>
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Profits<br/><small>(in  <b>₹ Crore</b>)</small>
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th><a href="/wiki/List_of_public_sector_undertakings_in_India" title="List of public sector undertakings in India">State Controlled</a>
#  </th>]

# %%
world_titles = table.find_all('th')
print(world_titles)
# Out:
# [<th>Rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Revenue<br/><small>(in  <b>₹ Crore</b>)</small>
# </th>, <th>Revenue growth
# </th>, <th>Profits<br/><small>(in  <b>₹ Crore</b>)</small>
# </th>, <th>Headquarters
# </th>, <th><a href="/wiki/List_of_public_sector_undertakings_in_India" title="List of public sector undertakings in India">State Controlled</a>
# </th>]

# %%
world_titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue<br/><small>(in  <b>₹ Crore</b>)</small>
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Profits<br/><small>(in  <b>₹ Crore</b>)</small>
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th><a href="/wiki/List_of_public_sector_undertakings_in_India" title="List of public sector undertakings in India">State Controlled</a>
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]

# %%
print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue(in  ₹ Crore)', 'Revenue growth', 'Profits(in  ₹ Crore)', 'Headquarters', 'State Controlled']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue(in  ₹ Crore), Revenue growth, Profits(in  ₹ Crore), Headquarters, State Controlled]
# Index: []

# %%
col_data = table.find_all('tr')

# %%
for row in col_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank                             Name            Industry  \
# 0     1      Reliance Industries Limited         Oil and gas
# 1     2           Indian Oil Corporation         Oil and gas
# 2     3       Life Insurance Corporation           Insurance
# 3     4  Oil and Natural Gas Corporation         Oil and gas
# 4     5                 Bharat Petroleum         Oil and gas
# 5     6              State Bank of India             Banking
# 6     7                      Tata Motors          Automotive
# 7     8                       Tata Steel      Iron and steel
# 8     9        Tata Consultancy Services            Infotech
# 9    10              Hindalco Industries   Metals and mining
# 10   11                        HDFC Bank             Banking
# 11   12                  Larsen & Toubro       Capital goods
# 12   13                       ICICI Bank             Banking
# 13   14                     NTPC Limited           Utilities
# ...

# %%
df.to_csv(r'C:\Users\HP\Desktop\Web Scrapping\Top Companies.csv', index = False)

# %%
df.head()
# Out:
#   Rank                             Name     Industry Revenue(in  ₹ Crore)  \
# 0    1      Reliance Industries Limited  Oil and gas              920,274
# 1    2           Indian Oil Corporation  Oil and gas              872,093
# 2    3       Life Insurance Corporation    Insurance              792,427
# 3    4  Oil and Natural Gas Corporation  Oil and gas              638,965
# 4    5                 Bharat Petroleum  Oil and gas              477,855
#
#   Revenue growth Profits(in  ₹ Crore) Headquarters State Controlled
# 0            25%               66,702       Mumbai
# 1            25%                9,792    New Delhi              Yes
# 2             9%               35,997       Mumbai              Yes
# 3            27%               35,440    New Delhi              Yes
# 4            34%                2,131       Mumbai              Yes
